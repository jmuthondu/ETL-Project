# %%
import pandas as pd
import numpy as np

# %%
# import female Datbase of all mortality .
female_df=pd.read_csv('Resources/ghe2016_deaths_country_fmle.csv')

# %%
#see the columns 
female_df.head()
# Out:
#   iso3  cause2015   causename   sex  age    agegroup      dths2000  \
# 0  AFG          0  All Causes  FMLE    0    DAYS0-28  26764.821370
# 1  AFG          0  All Causes  FMLE    1  MONTHS1-11  15750.902448
# 2  AFG          0  All Causes  FMLE    2      AGE1-4  19664.757133
# 3  AFG          0  All Causes  FMLE    5      AGE5-9   2508.298132
# 4  AFG          0  All Causes  FMLE   10    AGE10-14   1820.659095
#
#       low2000     upp2000      dths2001  ...     upp2013      dths2014  \
# 0  15058.6770  39608.6330  26971.029770  ...  34486.1370  21311.807304
# 1  11689.6850  19567.3180  16471.977529  ...  10184.7390   8204.524802
# 2  14014.4910  25955.3520  20875.082934  ...  17008.3180  11008.829403
# 3   2123.6943   2959.8584   2472.039087  ...   3981.2473   3445.186726
# 4   1576.7042   2109.8528   1754.717650  ...   2382.3301   2190.501407
#
#       low2014     upp2014      dths2015     low2015     upp2015      dths2016  \
# ...

# %%
#Dropping unnecessary columns
to_drop = ['low2000','upp2000','low2001','upp2001','low2002','upp2002','low2003','upp2003','low2004','upp2004',
          'low2005','upp2005','low2006','upp2006','low2007','upp2007','low2008','upp2008','low2009','upp2009',
          'low2010','upp2010','low2011','upp2011','low2012','upp2012','low2013','upp2013','low2014','upp2014',
          'low2015','upp2015','low2016','upp2016']
female_df.drop(to_drop, inplace=True, axis=1)

# %%
# dataframe aftre dopping unnessacry columns
female_df.head()
# Out:
#   iso3  cause2015   causename   sex  age    agegroup      dths2000  \
# 0  AFG          0  All Causes  FMLE    0    DAYS0-28  26764.821370
# 1  AFG          0  All Causes  FMLE    1  MONTHS1-11  15750.902448
# 2  AFG          0  All Causes  FMLE    2      AGE1-4  19664.757133
# 3  AFG          0  All Causes  FMLE    5      AGE5-9   2508.298132
# 4  AFG          0  All Causes  FMLE   10    AGE10-14   1820.659095
#
#        dths2001      dths2002      dths2003  ...      dths2007      dths2008  \
# 0  26971.029770  26995.269997  27148.130325  ...  26163.202191  25572.753917
# 1  16471.977529  14727.799878  12794.405244  ...  11733.697126  11291.189741
# 2  20875.082934  18960.856785  16839.137011  ...  15963.871140  15515.835798
# 3   2472.039087   2457.277514   2495.548944  ...   3061.253331   3087.940085
# 4   1754.717650   1634.065695   1616.181625  ...   1859.115361   1839.634945
#
#        dths2009      dths2010      dths2011      dths2012      dths2013  \
# ...

# %%
# check if there is Null value 
female_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786900 entries, 0 to 786899
# Data columns (total 23 columns):
# iso3         786900 non-null object
# cause2015    786900 non-null int64
# causename    786900 non-null object
# sex          786900 non-null object
# age          786900 non-null int64
# agegroup     786900 non-null object
# dths2000     786900 non-null float64
# dths2001     786900 non-null float64
# dths2002     786900 non-null float64
# dths2003     786900 non-null float64
# dths2004     786900 non-null float64
# dths2005     786900 non-null float64
# dths2006     786900 non-null float64
# dths2007     786900 non-null float64
# dths2008     786900 non-null float64
# dths2009     786900 non-null float64
# dths2010     786900 non-null float64
# dths2011     786900 non-null float64
# dths2012     786900 non-null float64
# dths2013     786900 non-null float64
# dths2014     786900 non-null float64
# dths2015     786900 non-null float64
# ...

# %%
type(base_df.causename)
# Out:
# pandas.core.series.Series

# %%
#Filtering the column with causename just being cancer

fem_cancer_df=female_df[female_df['causename'].str.contains('cancer')].copy()

# %%
#see the data filtered just for death caused by cancer 
fem_cancer_df.head()
# Out:
#      iso3  cause2015                     causename   sex  age    agegroup  \
# 1280  AFG        620  Mouth and oropharynx cancers  FMLE    0    DAYS0-28
# 1281  AFG        620  Mouth and oropharynx cancers  FMLE    1  MONTHS1-11
# 1282  AFG        620  Mouth and oropharynx cancers  FMLE    2      AGE1-4
# 1283  AFG        620  Mouth and oropharynx cancers  FMLE    5      AGE5-9
# 1284  AFG        620  Mouth and oropharynx cancers  FMLE   10    AGE10-14
#
#       dths2000  dths2001  dths2002  dths2003  ...  dths2007  dths2008  \
# 1280  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 1281  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 1282  1.819618  1.949925  2.231310  1.613118  ...  1.746218  1.984320
# 1283  0.431413  0.450303  0.473791  0.570633  ...  0.699484  0.700434
# 1284  0.436319  0.457119  0.480063  0.545550  ...  0.655512  0.676733
#
#       dths2009  dths2010  dths2011  dths2012  dths2013  dths2014  dths2015  \
# ...

# %%
# nor , read male data frame ,same fromat as fenake  and we do same procedure 
male_df = pd.read_csv('Resources/ghe2016_deaths_country_mle.csv')

# %%
male_df.head()
# Out:
#   iso3  cause2015   causename  sex  age    agegroup      dths2000     low2000  \
# 0  AFG          0  All Causes  MLE    0    DAYS0-28  34104.085855  19187.9630
# 1  AFG          0  All Causes  MLE    1  MONTHS1-11  13392.743857   9939.5547
# 2  AFG          0  All Causes  MLE    2      AGE1-4  17956.594144  12797.1340
# 3  AFG          0  All Causes  MLE    5      AGE5-9   2589.259186   2191.8733
# 4  AFG          0  All Causes  MLE   10    AGE10-14   1934.663746   1675.1927
#
#       upp2000      dths2001  ...     upp2013      dths2014     low2014  \
# 0  50469.8400  34417.639744  ...  43667.7810  26970.986787  13565.5950
# 1  16637.7810  14211.961764  ...   9223.0635   7471.876718   6289.5933
# 2  23700.7600  19270.847757  ...  16367.6970  10806.850964   6418.1597
# 3   3055.2532   2562.007143  ...   4353.9116   3797.981101   3092.3726
# 4   2241.8728   1833.030620  ...   2556.8005   2421.121936   2028.0482
#
# ...

# %%
#Dropping unnecessary columns
to_drop = ['low2000','upp2000','low2001','upp2001','low2002','upp2002','low2003','upp2003','low2004','upp2004',
          'low2005','upp2005','low2006','upp2006','low2007','upp2007','low2008','upp2008','low2009','upp2009',
          'low2010','upp2010','low2011','upp2011','low2012','upp2012','low2013','upp2013','low2014','upp2014',
          'low2015','upp2015','low2016','upp2016']
male_df.drop(to_drop, inplace=True, axis=1)

# %%
male_df.head()
# Out:
#   iso3  cause2015   causename  sex  age    agegroup      dths2000  \
# 0  AFG          0  All Causes  MLE    0    DAYS0-28  34104.085855
# 1  AFG          0  All Causes  MLE    1  MONTHS1-11  13392.743857
# 2  AFG          0  All Causes  MLE    2      AGE1-4  17956.594144
# 3  AFG          0  All Causes  MLE    5      AGE5-9   2589.259186
# 4  AFG          0  All Causes  MLE   10    AGE10-14   1934.663746
#
#        dths2001      dths2002      dths2003  ...      dths2007      dths2008  \
# 0  34417.639744  34695.441270  34651.858148  ...  33136.169305  32408.489602
# 1  14211.961764  12761.078033  11396.710123  ...  10781.281020  10322.082357
# 2  19270.847757  17186.143954  15448.128402  ...  15137.871574  14719.905232
# 3   2562.007143   2526.109515   2601.871188  ...   3281.686487   3314.538305
# 4   1833.030620   1567.600069   1554.022210  ...   1956.888129   1929.143943
#
#        dths2009      dths2010      dths2011      dths2012      dths2013  \
# ...

# %%
#Filtering the column with causename just being cancer

male_cancer_df=male_df[male_df['causename'].str.contains('cancer')].copy()

# %%
male_cancer_df.head()
# Out:
#      iso3  cause2015                     causename  sex  age    agegroup  \
# 1280  AFG        620  Mouth and oropharynx cancers  MLE    0    DAYS0-28
# 1281  AFG        620  Mouth and oropharynx cancers  MLE    1  MONTHS1-11
# 1282  AFG        620  Mouth and oropharynx cancers  MLE    2      AGE1-4
# 1283  AFG        620  Mouth and oropharynx cancers  MLE    5      AGE5-9
# 1284  AFG        620  Mouth and oropharynx cancers  MLE   10    AGE10-14
#
#        dths2000   dths2001   dths2002  dths2003  ...   dths2007   dths2008  \
# 1280   0.000000   0.000000   0.000000  0.000000  ...   0.000000   0.000000
# 1281   0.000000   0.000000   0.000000  0.000000  ...   0.000000   0.000000
# 1282  10.908418  11.716747  13.477168  9.804761  ...  10.621755  12.003604
# 1283   2.178087   2.261998   2.368097  2.599647  ...   3.048928   3.101004
# 1284   2.013921   2.088799   2.172967  2.290196  ...   2.644033   2.743910
#
#        dths2009   dths2010   dths2011   dths2012   dths2013   dths2014  \
# ...

# %%
#check for the null value
male_cancer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91500 entries, 1280 to 784459
# Data columns (total 23 columns):
# iso3         91500 non-null object
# cause2015    91500 non-null int64
# causename    91500 non-null object
# sex          91500 non-null object
# age          91500 non-null int64
# agegroup     91500 non-null object
# dths2000     91500 non-null float64
# dths2001     91500 non-null float64
# dths2002     91500 non-null float64
# dths2003     91500 non-null float64
# dths2004     91500 non-null float64
# dths2005     91500 non-null float64
# dths2006     91500 non-null float64
# dths2007     91500 non-null float64
# dths2008     91500 non-null float64
# dths2009     91500 non-null float64
# dths2010     91500 non-null float64
# dths2011     91500 non-null float64
# dths2012     91500 non-null float64
# dths2013     91500 non-null float64
# dths2014     91500 non-null float64
# dths2015     91500 non-null float64
# dths2016     91500 non-null float64
# ...

# %%
# now put two data frame male and female in one big dtaframe
both_cancer = pd.concat([fem_cancer_df,male_cancer_df], axis=0)

# %%
#rest the index 
both_cancer.reset_index(drop = True)
# Out:
#        iso3  cause2015                     causename   sex  age    agegroup  \
# 0       AFG        620  Mouth and oropharynx cancers  FMLE    0    DAYS0-28
# 1       AFG        620  Mouth and oropharynx cancers  FMLE    1  MONTHS1-11
# 2       AFG        620  Mouth and oropharynx cancers  FMLE    2      AGE1-4
# 3       AFG        620  Mouth and oropharynx cancers  FMLE    5      AGE5-9
# 4       AFG        620  Mouth and oropharynx cancers  FMLE   10    AGE10-14
# 5       AFG        620  Mouth and oropharynx cancers  FMLE   15    AGE15-19
# 6       AFG        620  Mouth and oropharynx cancers  FMLE   20    AGE20-24
# 7       AFG        620  Mouth and oropharynx cancers  FMLE   25    AGE25-29
# 8       AFG        620  Mouth and oropharynx cancers  FMLE   30    AGE30-34
# 9       AFG        620  Mouth and oropharynx cancers  FMLE   35    AGE35-39
# 10      AFG        620  Mouth and oropharynx cancers  FMLE   40    AGE40-44
# ...

# %%
# This is 2nd dsat frame , gdp of all countries from 1960 to now .
gdp_df=pd.read_csv('Resources/world_gdp.csv')

# %%
# see the filed and null value 
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 64 columns):
# Country Name      264 non-null object
# Country Code      264 non-null object
# Indicator Name    264 non-null object
# Indicator Code    264 non-null object
# 1960              133 non-null float64
# 1961              134 non-null float64
# 1962              136 non-null float64
# 1963              136 non-null float64
# 1964              136 non-null float64
# 1965              146 non-null float64
# 1966              147 non-null float64
# 1967              150 non-null float64
# 1968              154 non-null float64
# 1969              154 non-null float64
# 1970              163 non-null float64
# 1971              164 non-null float64
# 1972              164 non-null float64
# 1973              164 non-null float64
# 1974              165 non-null float64
# 1975              169 non-null float64
# 1976              170 non-null float64
# ...

# %%
# see the columns and data format
gdp_df.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
# ...

# %%
# just select the column wee need including only year 2020 to 2016
new_gdp = gdp_df[['Country Name','Country Code','2000','2001',
          '2002','2003','2004','2005','2006','2007',
          '2008','2009','2010','2011','2012','2013',
          '2014','2015','2016']]
new_gdp.head()
# Out:
#   Country Name Country Code          2000          2001          2002  \
# 0        Aruba          ABW  1.873453e+09  1.920112e+09  1.941341e+09
# 1  Afghanistan          AFG           NaN           NaN  4.055177e+09
# 2       Angola          AGO  9.129595e+09  8.936064e+09  1.528559e+10
# 3      Albania          ALB  3.480355e+09  3.922099e+09  4.348070e+09
# 4      Andorra          AND  1.434430e+09  1.496913e+09  1.733117e+09
#
#            2003          2004          2005          2006          2007  \
# 0  2.021229e+09  2.228492e+09  2.330726e+09  2.424581e+09  2.615084e+09
# 1  4.515563e+09  5.226775e+09  6.209140e+09  6.971287e+09  9.747886e+09
# 2  1.781271e+10  2.355205e+10  3.697092e+10  5.238101e+10  6.526645e+10
# 3  5.611492e+09  7.184681e+09  8.052076e+09  8.896074e+09  1.067732e+10
# 4  2.398646e+09  2.935659e+09  3.255789e+09  3.543257e+09  4.016972e+09
#
#            2008          2009          2010          2011          2012  \
# ...

# %%
#fill missing value using interpolte technique ,and using current data to estimate null value
new_gdp.interpolate(method ='linear', limit_direction ='forward')
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
# rename  one colum in both cancer withe same name in gdp 'country code"
both_cancer.rename(columns={'iso3': 'Country Code'}, inplace=True)

# %%
# now merge two main data frme  to get one master data frame
master_data = pd.merge(both_cancer,new_gdp,on=['Country Code'])

# %%
master_data
# Out:
#        Country Code  cause2015                     causename   sex  age  \
# 0               AFG        620  Mouth and oropharynx cancers  FMLE    0
# 1               AFG        620  Mouth and oropharynx cancers  FMLE    1
# 2               AFG        620  Mouth and oropharynx cancers  FMLE    2
# 3               AFG        620  Mouth and oropharynx cancers  FMLE    5
# 4               AFG        620  Mouth and oropharynx cancers  FMLE   10
# 5               AFG        620  Mouth and oropharynx cancers  FMLE   15
# 6               AFG        620  Mouth and oropharynx cancers  FMLE   20
# 7               AFG        620  Mouth and oropharynx cancers  FMLE   25
# 8               AFG        620  Mouth and oropharynx cancers  FMLE   30
# 9               AFG        620  Mouth and oropharynx cancers  FMLE   35
# 10              AFG        620  Mouth and oropharynx cancers  FMLE   40
# 11              AFG        620  Mouth and oropharynx cancers  FMLE   45
# ...

# %%
#save data as CSV file 
master_data.to_csv('Cleaned data/master_data.csv')

# %%
# save Data as Json file
master_data.to_json('Cleaned data/master_data.json')

# %%
#save data s Postgres table in ETL_project file 
from sqlalchemy import create_engine
engine = create_engine(f'postgresql+psycopg2://postgres:postgres@localhost/ETL-PROJECT') 
#engine = create_engine('postgresql://localhost:5432/<your_db_name>')
conn = engine.connect()
master_data.to_sql('master_data', engine)
