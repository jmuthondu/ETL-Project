# %%
import pandas as pd

# %%
base_df=pd.read_csv('Resources/Popular_ Indicators -Ecomomy _indictors/population-economy.csv')

# %%
base_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 778 entries, 0 to 777
# Data columns (total 15 columns):
# ISO                              777 non-null object
# Country                          776 non-null object
# Subject Descriptor               776 non-null object
# Units                            776 non-null object
# Scale                            582 non-null object
# Country/Series-specific Notes    694 non-null object
# 2017                             689 non-null object
# 2018                             683 non-null object
# 2019                             680 non-null object
# 2020                             680 non-null object
# 2021                             680 non-null object
# 2022                             680 non-null object
# 2023                             680 non-null object
# 2024                             680 non-null object
# Estimates Start After            693 non-null float64
# dtypes: float64(1), object(14)
# memory usage: 91.2+ KB

# %%
base_df.columns
# Out:
# Index(['ISO', 'Country', 'Subject Descriptor', 'Units', 'Scale',
#        'Country/Series-specific Notes', '2017', '2018', '2019', '2020', '2021',
#        '2022', '2023', '2024', 'Estimates Start After'],
#       dtype='object')

# %%
base_df['Subject Descriptor'].value_counts()
# Out:
# Unemployment rate                                     194
# Gross domestic product per capita, constant prices    194
# Population                                            194
# Gross domestic product, constant prices               194
# Name: Subject Descriptor, dtype: int64

# %%
unemployment_df=base_df.loc[base_df['Subject Descriptor']=='Unemployment rate'].copy()

# %%
unemployment_df.drop(columns=['Scale',)
# Out:
#      ISO                   Country Subject Descriptor  \
# 2    AFG               Afghanistan  Unemployment rate
# 6    ALB                   Albania  Unemployment rate
# 10   DZA                   Algeria  Unemployment rate
# 14   AGO                    Angola  Unemployment rate
# 18   ATG       Antigua and Barbuda  Unemployment rate
# 22   ARG                 Argentina  Unemployment rate
# 26   ARM                   Armenia  Unemployment rate
# 30   ABW                     Aruba  Unemployment rate
# 34   AUS                 Australia  Unemployment rate
# 38   AUT                   Austria  Unemployment rate
# 42   AZE                Azerbaijan  Unemployment rate
# 46   BHS               The Bahamas  Unemployment rate
# 50   BHR                   Bahrain  Unemployment rate
# 54   BGD                Bangladesh  Unemployment rate
# 58   BRB                  Barbados  Unemployment rate
# 62   BLR                   Belarus  Unemployment rate
# ...

# %%
#unemployment_df.fillna(0,inplace=True)
unemployment_df.dropna(inplace=True)

# %%
unemployment_df['average']=(unemployment_df['2017'].apply(lambda x: float(x))+\
unemployment_df['2018'].apply(lambda x: float(x))+\
unemployment_df['2019'].apply(lambda x: float(x))+\
unemployment_df['2020'].apply(lambda x: float(x))+\
unemployment_df['2021'].apply(lambda x: float(x)))/5


                            
unemployment_df
# Out:
# Empty DataFrame
# Columns: [ISO, Country, Subject Descriptor, Units, Scale, Country/Series-specific Notes, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, Estimates Start After, average]
# Index: []

# %%
gdp_df=base_df.loc[base_df['Subject Descriptor']=='Gross domestic product, constant prices'].copy()

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 194 entries, 0 to 772
# Data columns (total 15 columns):
# ISO                              194 non-null object
# Country                          194 non-null object
# Subject Descriptor               194 non-null object
# Units                            194 non-null object
# Scale                            194 non-null object
# Country/Series-specific Notes    194 non-null object
# 2017                             193 non-null object
# 2018                             193 non-null object
# 2019                             193 non-null object
# 2020                             193 non-null object
# 2021                             193 non-null object
# 2022                             193 non-null object
# 2023                             193 non-null object
# 2024                             193 non-null object
# Estimates Start After            194 non-null float64
# dtypes: float64(1), object(14)
# memory usage: 24.2+ KB

# %%
gdp_df.dropna(inplace=True)
gdp_df.head()
# Out:
#     ISO              Country                       Subject Descriptor  \
# 0   AFG          Afghanistan  Gross domestic product, constant prices
# 4   ALB              Albania  Gross domestic product, constant prices
# 8   DZA              Algeria  Gross domestic product, constant prices
# 12  AGO               Angola  Gross domestic product, constant prices
# 16  ATG  Antigua and Barbuda  Gross domestic product, constant prices
#
#                 Units     Scale  \
# 0   National currency  Billions
# 4   National currency  Billions
# 8   National currency  Billions
# 12  National currency  Billions
# 16  National currency  Billions
#
#                         Country/Series-specific Notes      2017      2018  \
# 0   Source: National Statistics Office Latest actu...   506.215   517.858
# 4   Source: IMF Staff Estimates Latest actual data...   789.653   822.522
# 8   Source: National Statistics Office Latest actu...  7,371.95  7,523.77
# ...

# %%
#gdp_df['average']=gdp_df['2017'].apply(lambda x: float(x))
a=gdp_df.loc[:,['2017','2018','2019','2020']].replace(',', '')
#gdp_df.replace()
a
# Out:
#              2017          2018          2019          2020
# 0         506.215       517.858       533.394       552.063
# 4         789.653       822.522        852.66       885.573
# 8        7,371.95      7,523.77      7,698.00      7,834.77
# 12       1,586.58      1,559.62      1,566.54      1,611.68
# 16          3.333          3.51          3.65          3.77
# 20        725.331       707.092       698.598       713.715
# 24       3,619.71      3,801.72      3,974.93      4,153.81
# 28          3.407         3.448         3.472         3.504
# 32       1,787.33      1,837.57      1,875.65      1,927.40
# 36        326.749       335.612       342.242        348.06
# 40         28.739        29.127        30.112        31.038
# 44         10.742        10.989         11.22          11.4
# 48          12.43        12.658        12.891        13.162
# 52       9,851.68     10,612.90     11,386.48     12,183.53
# 56          9.229         9.183         9.174         9.229
# ...

# %%
base_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118035 entries, 0 to 118034
# Data columns (total 57 columns):
# iso3         118035 non-null object
# cause2015    118035 non-null object
# causename    118035 non-null object
# sex          118035 non-null object
# age          118035 non-null object
# agegroup     118035 non-null object
# dths2000     118035 non-null object
# low2000      118035 non-null object
# upp2000      118035 non-null object
# dths2001     118035 non-null object
# low2001      118035 non-null object
# upp2001      118035 non-null object
# dths2002     118035 non-null object
# low2002      118035 non-null object
# upp2002      118035 non-null object
# dths2003     118035 non-null object
# low2003      118035 non-null object
# upp2003      118035 non-null object
# dths2004     118035 non-null object
# low2004      118035 non-null object
# upp2004      118035 non-null object
# dths2005     118035 non-null object
# low2005      118035 non-null object
# ...

# %%
pop_df=pd.read_csv('Resources/AAA-ghe2016_deaths_country_allages/population-economy.csv',nrows=10**4, dtype=object)

# %%
pop_df.head()
# Out:
#    ISO      Country                                 Subject Descriptor  \
# 0  AFG  Afghanistan            Gross domestic product, constant prices
# 1  AFG  Afghanistan  Gross domestic product per capita, constant pr...
# 2  AFG  Afghanistan                                  Unemployment rate
# 3  AFG  Afghanistan                                         Population
# 4  ALB      Albania            Gross domestic product, constant prices
#
#                           Units     Scale  \
# 0             National currency  Billions
# 1             National currency     Units
# 2  Percent of total labor force       NaN
# 3                       Persons  Millions
# 4             National currency  Billions
#
#                        Country/Series-specific Notes       2017       2018  \
# 0  Source: National Statistics Office Latest actu...    506.215    517.858
# 1  See notes for:  Gross domestic product, consta...  14,247.51  14,376.94
# ...

# %%
pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 778 entries, 0 to 777
# Data columns (total 15 columns):
# ISO                              777 non-null object
# Country                          776 non-null object
# Subject Descriptor               776 non-null object
# Units                            776 non-null object
# Scale                            582 non-null object
# Country/Series-specific Notes    694 non-null object
# 2017                             689 non-null object
# 2018                             683 non-null object
# 2019                             680 non-null object
# 2020                             680 non-null object
# 2021                             680 non-null object
# 2022                             680 non-null object
# 2023                             680 non-null object
# 2024                             680 non-null object
# Estimates Start After            693 non-null object
# dtypes: object(15)
# memory usage: 91.2+ KB
